# %% [markdown]
# <a href="https://colab.research.google.com/github/thokozani-msezane/MIT-805/blob/main/Assignement2_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Thokozani Msezane u15210830
#
# MIT 805: Big Data
#
# Assignement 2

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2023.7.22)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4)

# %%
# !git config --global user.email "u15210830@tuks.co.za"
# !git config --global user.name "thokozani-msezane"

# %%
#!git clone https://github.com/<username>/<repository>.git

# !git clone https://github.com/thokozani-msezane/thokozani-msezane.git
# Out:
# Cloning into 'thokozani-msezane'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! mkdir ~/.kaggle

# %%
# !cp /content/drive/MyDrive/MIT805/kaggle.json ~/.kaggle/kaggle.json

# %%
# !mkdir '/content/input_data/'

# %%
! kaggle datasets download bwandowando/ukraine-russian-crisis-twitter-dataset-1-2-m-rows
# Out:
# Downloading ukraine-russian-crisis-twitter-dataset-1-2-m-rows.zip to /content/drive/MyDrive/MIT805/Input
# 100% 16.7G/16.7G [06:42<00:00, 52.6MB/s]
# 100% 16.7G/16.7G [06:42<00:00, 44.4MB/s]

# %%
# !mv '/content/ukraine-russian-crisis-twitter-dataset-1-2-m-rows.zip' '/content/input
# Out:
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `''
# /bin/bash: -c: line 2: syntax error: unexpected end of file

# %%
#!cd '/content/input_data'
import os
#/content/drive/MyDrive/MIT805/Input

os.chdir('/content/drive/MyDrive/MIT805/Input/')

# %%
# !pwd
# Out:
# /content/drive/MyDrive/MIT805/Input

# %%
! unzip '/content/drive/MyDrive/MIT805/Input/ukraine-russian-crisis-twitter-dataset-1-2-m-rows.zip'
# Out:
# Archive:  /content/drive/MyDrive/MIT805/Input/ukraine-russian-crisis-twitter-dataset-1-2-m-rows.zip
#   inflating: 0819_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0820_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0821_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0822_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0823_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0824_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0825_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0826_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0827_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0828_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0829_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0830_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0831_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0901_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0902_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0903_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0904_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0905_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0906_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0907_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0908_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0909_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0910_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0911_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0912_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0913_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0914_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0915_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0916_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0917_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0918_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0919_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0920_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0921_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0922_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0923_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0924_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0925_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0926_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0927_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0928_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0929_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 0930_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1001_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1002_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1003_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1004_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1005_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1006_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1007_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1008_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1009_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1010_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1011_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1012_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1013_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1014_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1015_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1016_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1017_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1018_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1019_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1020_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1021_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1022_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1023_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1024_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1025_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1026_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1027_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1028_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1029_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1030_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1031_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1101_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1102_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1103_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1104_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1105_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1106_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1107_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1108_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1109_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1110_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1111_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1112_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1113_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1114_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1115_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1116_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1117_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1118_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1119_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1120_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1121_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1122_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1123_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1124_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1125_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1126_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1127_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1128_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1129_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1130_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1201_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1202_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1203_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1204_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1205_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1206_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1207_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1208_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1209_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1210_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1211_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1212_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1213_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1214_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1215_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1216_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1217_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1218_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1219_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1220_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1221_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1222_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1223_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1224_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1225_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1226_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1227_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1228_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1229_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1230_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 1231_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230101_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230102_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230103_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230104_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230105_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230106_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230107_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230108_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230109_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230110_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230111_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230112_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230113_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230114_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230115_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230116_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230117_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230118_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230119_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230120_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230121_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230122_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230123_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230124_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230125_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230126_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230127_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230128_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230129_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230130_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230131_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230201_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230202_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230203_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230204_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230205_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230206_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230207_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230208_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230209_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230210_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230211_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20230212_UkraineCombinedTweetsDeduped.csv.gzip
#   inflating: 20
UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230331_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230401_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230402_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230403_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230404_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230405_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230406_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230407_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230408_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230409_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230410_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230411_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230412_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230413_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230414_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230415_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230416_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230417_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230418_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230419_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230420_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230421_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230422_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230423_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230424_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230425_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230426_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230427_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230428_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230429_to_20230430_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230501_to_20230502_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230503_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230504_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230505_to_20230508_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230509_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230510_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230511_to_20230512_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230513_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230514_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230515_to_20230516_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230517_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230518_to_20230520_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230521_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230522_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230523_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230524_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230525_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230526_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230527_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230528_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230529_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230530_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230531_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230601_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230602_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230603_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230604_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230605_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230606_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230607_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230608_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230609_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230610_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230611_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230612_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230613_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/20230614_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0401_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0402_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0403_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0404_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0405_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0406_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0407_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0408_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0409_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0410_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0411_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0412_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0413_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0414_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0415_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0416_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0417_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0418_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0419_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0420_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0421_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0422_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0423_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0424_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0425_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0426_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0427_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0428_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0429_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0430_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0501_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0502_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0503_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0504_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0505_to_0507_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0508_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0509_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0510_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0511_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0512_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0513_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0514_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0515_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0516_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0517_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0518_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0519_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0520_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0521_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0522_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0523_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0524_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0525_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0526_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0527_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0528_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0529_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0530_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0531_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0601_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0602_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0603_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0604_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0605_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0606_to_08_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0609_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0610_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0611_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0612_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0613_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0614_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0615_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0616_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0617_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0618_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0619_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0620_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0621_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0622_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0623_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0624_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0625_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0626_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0627_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0628_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0629_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0630_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0701_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0702_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0703_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0704_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0705_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0706_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0707_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0708_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0709_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0710_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0711_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0712_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0713_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0714_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0715_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0716_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0717_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0718_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0719_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0720_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0721_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0722_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0723_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0724_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0725_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0726_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0727_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0728_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0729_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0730_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0731_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0801_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0802_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0803_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0804_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0805_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0806_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0807_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0808_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0809_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0810_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0811_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0812_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0813_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0814_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0815_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0816_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0817_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/0818_UkraineCombinedTweetsDeduped.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped20220227-131611.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_FEB27.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_FEB28_part1.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_FEB28_part2.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR01.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR02.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR03.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR04.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR05.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR06.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR07.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR08.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR09.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR10.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR11.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR12.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR13.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR14.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR15.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR16.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR17.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR18.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR19.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR20.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR21.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR22.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR23.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR24.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR25.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR26.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR27_to_28.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR29.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR30.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/UkraineWar/UkraineWar/UkraineCombinedTweetsDeduped_MAR31.csv.gzip',
#  '/content/drive/MyDrive/MIT805/Input/ukraine-russian-crisis-twitter-dataset-1-2-m-rows.zip']

# %%
import csv
import gc
from pathlib import Path

columns = ["tweetcreatedts","extractedts","tweetid"]

dataframe_collection = []
for csvfile in files:
    df = pd.read_csv(csvfile, engine='python', compression='gzip',encoding='utf-8', quoting=csv.QUOTE_ALL, usecols=lambda x: x in columns)
    dataframe_collection.append(df)

df = None
del df
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ec40411d9f5b> in <cell line: 8>()
#       7 dataframe_collection = []
#       8 for csvfile in files:
# ----> 9     df = pd.read_csv(csvfile, engine='python', compression='gzip',encoding='utf-8', quoting=csv.QUOTE_ALL, usecols=lambda x: x in columns)
#      10     dataframe_collection.append(df)
#      11
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     609
#     610     with parser:
# --> 611         return parser.read(nrows)
#     612
#     613
#
# KeyboardInterrupt:

# %%
import csv
import gc
from pathlib import Path

columns = ["tweetid", "location", "text", "language"]

dataframe_collection2 = []
for csvfile in files:
    df = pd.read_csv(csvfile, engine='python', compression='gzip',encoding='utf-8', quoting=csv.QUOTE_ALL, usecols=lambda x: x in columns)
    dataframe_collection2.append(df)

df = None
del df
gc.collect()
# Out:
# 33

# %%
df_combined = pd.concat(dataframe_collection2, axis=0)
#df_combined['tweetcreatedts'] = pd.to_datetime(df_combined['tweetcreatedts'], errors='coerce')
#df_combined['extractedts'] = pd.to_datetime(df_combined['extractedts'], errors='coerce')
df_combined.reset_index(inplace=True, drop=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-8031e339f378> in <cell line: 1>()
# ----> 1 df_combined = pd.concat(dataframe_collection2, axis=0)
#       2 #df_combined['tweetcreatedts'] = pd.to_datetime(df_combined['tweetcreatedts'], errors='coerce')
#       3 #df_combined['extractedts'] = pd.to_datetime(df_combined['extractedts'], errors='coerce')
#       4 df_combined.reset_index(inplace=True, drop=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379     )
#     380
# --> 381     return op.get_result()
#     382
#     383
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in get_result(self)
#     614                 mgrs_indexers.append((obj._mgr, indexers))
#     615
# --> 616             new_data = concatenate_managers(
#     617                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     618             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/concat.py in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     231             fastpath = blk.values.dtype == values.dtype
#     232         else:
# --> 233             values = _concatenate_join_units(join_units, concat_axis, copy=copy)
#     234             fastpath = False
#     235
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/concat.py in _concatenate_join_units(join_units, concat_axis, copy)
#     540     upcasted_na = _dtype_to_na_value(empty_dtype, has_none_blocks)
#     541
# --> 542     to_concat = [
#     543         ju.get_reindexed_values(empty_dtype=empty_dtype, upcasted_na=upcasted_na)
#     544         for ju in join_units
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/concat.py in <listcomp>(.0)
#     541
#     542     to_concat = [
# --> 543         ju.get_reindexed_values(empty_dtype=empty_dtype, upcasted_na=upcasted_na)
#     544         for ju in join_units
#     545     ]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/concat.py in get_reindexed_values(self, empty_dtype, upcasted_na)
#     520         else:
#     521             for ax, indexer in self.indexers.items():
# --> 522                 values = algos.take_nd(values, indexer, axis=ax)
#     523
#     524         return values
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/array_algos/take.py in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     115
#     116     arr = np.asarray(arr)
# --> 117     return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     118
#     119
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/array_algos/take.py in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     161         arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     162     )
# --> 163     func(arr, indexer, out, fill_value)
#     164
#     165     if flip_order:
#
# KeyboardInterrupt:

# %%
df_combined2 = pd.concat(dataframe_collection2, axis=0)
#df_combined['tweetcreatedts'] = pd.to_datetime(df_combined['tweetcreatedts'], errors='coerce')
#df_combined['extractedts'] = pd.to_datetime(df_combined['extractedts'], errors='coerce')
df_combined2.reset_index(inplace=True, drop=True)

# %%
dataframe_collection = None
del dataframe_collection
gc.collect()
# Out:
# 0

# %%
dataframe_collection2 = None
del dataframe_collection2
gc.collect()
# Out:
# 0

# %%
df_combined2.shape
# Out:
# (13141766, 4)

# %%
df_combined2.sort_values(["tweetid","extractedts"], ascending=True,inplace=True)
df_combined2.drop_duplicates(["tweetid"],keep='last',inplace=True)
df_combined2.sort_values(['tweetcreatedts',"tweetid"], ascending=True,inplace=True)
df_combined2.reset_index(drop=True, inplace=True)
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-1f391fdf012a> in <cell line: 1>()
# ----> 1 df_combined2.sort_values(["tweetid","extractedts"], ascending=True,inplace=True)
#       2 df_combined2.drop_duplicates(["tweetid"],keep='last',inplace=True)
#       3 df_combined2.sort_values(['tweetcreatedts',"tweetid"], ascending=True,inplace=True)
#       4 df_combined2.reset_index(drop=True, inplace=True)
#       5 gc.collect()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6892         if len(by) > 1:
#    6893
# -> 6894             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6895
#    6896             # need to rewrap columns in Series to apply key function
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in <listcomp>(.0)
#    6892         if len(by) > 1:
#    6893
# -> 6894             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6895
#    6896             # need to rewrap columns in Series to apply key function
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1848             )
#    1849         else:
# -> 1850             raise KeyError(key)
#    1851
#    1852         # Check for duplicates
#
# KeyError: 'extractedts'

# %%
#columns = ["tweetid", "location", "text", "language"]

df_combined.sort_values(["tweetid","location"], ascending=True,inplace=True)
df_combined.drop_duplicates(["tweetid"],keep='last',inplace=True)
df_combined.sort_values(['text',"tweetid"], ascending=True,inplace=True)
df_combined.sort_values(['language',"text"], ascending=True,inplace=True)
df_combined.reset_index(drop=True, inplace=True)
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-2a2c9a34ffca> in <cell line: 3>()
#       1 #columns = ["tweetid", "location", "text", "language"]
#       2
# ----> 3 df_combined.sort_values(["tweetid","location"], ascending=True,inplace=True)
#       4 df_combined.drop_duplicates(["tweetid"],keep='last',inplace=True)
#       5 df_combined.sort_values(['text',"tweetid"], ascending=True,inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6892         if len(by) > 1:
#    6893
# -> 6894             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6895
#    6896             # need to rewrap columns in Series to apply key function
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in <listcomp>(.0)
#    6892         if len(by) > 1:
#    6893
# -> 6894             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6895
#    6896             # need to rewrap columns in Series to apply key function
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1848             )
#    1849         else:
# -> 1850             raise KeyError(key)
#    1851
#    1852         # Check for duplicates
#
# KeyError: 'location'

# %%
df_combined2.loc[df_combined2.duplicated(["tweetid"],keep=False)].sort_values("tweetid").head(6)
# Out:
# Empty DataFrame
# Columns: [location, tweetid, text, language]
# Index: []

# %%
df_combined2.shape
# Out:
# (13141766, 4)

# %%
df_combined2.head()
# Out:
#                          location              tweetid  \
# 0              Belém, PA - Brasil  1609338614646771714
# 1  #NAFO base on moon's dark side  1609338615011893249
# 2           Auckland, New Zealand  1609338623010406401
# 3                 Berlin, Germany  1609338623639359491
# 4                             NaN  1609338625417789443
#
#                                                 text language
# 0  Ataque em #Kiev na véspera de Ano Novo deixa a...       pt
# 1  Full video, I dare you not to shed a single te...       en
# 2  @RusMission_EU @mfa_russia @RusMission_OIC @am...       en
# 3  El presidente de #Ucrania🇺🇦 envió un mensaje d...       es
# 4  Téigh fuck féin, Putin!\n(Irish)\n\n#StandWith...       fi

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

df_combined.set_index('tweetcreatedts', drop=False, inplace=True)
df_combined.index = pd.to_datetime(df_combined.index)
df_weekly_aggregated = df_combined['tweetid'].groupby(pd.Grouper(freq='1w')).count()
df_weekly_aggregated.tail(20)
# Out:
# tweetcreatedts
# 2023-02-05     284912
# 2023-02-12     463546
# 2023-02-19     353952
# 2023-02-26     950864
# 2023-03-05    1134151
# 2023-03-12    1002008
# 2023-03-19    1121607
# 2023-03-26    1149268
# 2023-04-02     964227
# 2023-04-09     893903
# 2023-04-16     844869
# 2023-04-23     417670
# 2023-04-30     176989
# 2023-05-07     210320
# 2023-05-14     251223
# 2023-05-21     279464
# 2023-05-28     151013
# 2023-06-04     195916
# 2023-06-11     627092
# 2023-06-18     306658
# Freq: W-SUN, Name: tweetid, dtype: int64

# %%
ax = df_weekly_aggregated.plot(kind='bar', grid=False, figsize=(24,8), color='#86bf91', zorder=2, rot=45)

ax.set_title("Tweets Created Per Week In Dataset")
ax.set_xlabel("Date", labelpad=20, weight='bold', size=12)
ax.set_ylabel("Tweets", labelpad=20, weight='bold', size=12)

# Format y-axis label
ax.set_xticklabels([x.strftime("%b %d %Y") for x in df_weekly_aggregated.index])
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))
plt.show()

# %%
df_combined.to_csv("./time_series_tweets.csv", index=False)

# %%
df_combined2["text"].head(10)
# Out:
# 0    Full video, I dare you not to shed a single te...
# 1    @RusMission_EU @mfa_russia @RusMission_OIC @am...
# 2    Happy New Year to you all! From the UK! 🇬🇧 Wha...
# 3    The enemy conducted reconnaissance in battle  ...
# 4    Happy New Year, dear friends!!! Year of our vi...
# 5    The Night Cap Airs 6pm Pst to 7pm Pst https://...
# 6    @NataliiaKulak It is so depressing what you mu...
# 7    @ZelenskaUA All the best. May the force be wit...
# 8    Russian missiles strike Kyiv as Zelenskyy pled...
# 9    Russian missiles strike Kyiv as Zelenskyy pled...
# Name: text, dtype: object

# %%
print(f"There are {df_combined2['language'].nunique()} unique languages in this DataFrame.")
df_combined2["language"].unique()
# Out:
# There are 1 unique languages in this DataFrame.
# array(['en'], dtype=object)

# %%
df_combined2 = df_combined2.loc[df_combined2["language"]=="en"]
print(f"{df_combined2.shape[0]} rows are in English")
# Out:
# 7289856 rows are in English

# %%
7289856/13141766
# Out:
# 0.5547090094284132

# %%
# reset index
df_combined2.reset_index(inplace=True, drop=True)
# check
df_combined2.head(20)
# Out:
#                          location              tweetid  \
# 0  #NAFO base on moon's dark side  1609338615011893249
# 1           Auckland, New Zealand  1609338623010406401
# 2         England, United Kingdom  1609338628211150849
# 3                             NaN  1609338632762015745
# 4                       Berdyansk  1609338634842300419
#
#                                                 text language
# 0  Full video, I dare you not to shed a single te...       en
# 1  @RusMission_EU @mfa_russia @RusMission_OIC @am...       en
# 2  Happy New Year to you all! From the UK! 🇬🇧 Wha...       en
# 3  The enemy conducted reconnaissance in battle  ...       en
# 4  Happy New Year, dear friends!!! Year of our vi...       en

# %%
print(f"{round(df_combined2.loc[df_combined2['language']=='en'].shape[0]/df_combined2.shape[0]*100, 2)}% of the tweets are in English.")
# Out:
# 100.0% of the tweets are in English.

# %%
df_combined2.head(20)
# Out:
#                           location              tweetid  \
# 0   #NAFO base on moon's dark side  1609338615011893249
# 1            Auckland, New Zealand  1609338623010406401
# 2          England, United Kingdom  1609338628211150849
# 3                              NaN  1609338632762015745
# 4                        Berdyansk  1609338634842300419
# 5                    Las Vegas, NV  1609338646444019712
# 6                          Münster  1609338647261876224
# 7      Marche-en-Famenne, Belgique  1609338655423827981
# 8                              NaN  1609338659743973376
# 9                              NaN  1609338660633059336
# 10                             NaN  1609338672297418759
# 11                             NaN  1609338679440412674
# 12             Burlington, Ontario  1609338686012887043
# 13               Brampton, Ontario  1609338697777876992
# 14            Edmonton, AB, Canada  1609338698419810304
# 15                             NaN  1609338701175459841
# 16                       Hong Kong  1609338710545383430
# 17              Vestavia Hills, AL  1609338741641953282
# 18                             NaN  1609338743772561408
# 19                 London, England  1609338745731293185
#
#                                                  text language
# 0   Full video, I dare you not to shed a single te...       en
# 1   @RusMission_EU @mfa_russia @RusMission_OIC @am...       en
# 2   Happy New Year to you all! From the UK! 🇬🇧 Wha...       en
# 3   The enemy conducted reconnaissance in battle  ...       en
# 4   Happy New Year, dear friends!!! Year of our vi...       en
# 5   The Night Cap Airs 6pm Pst to 7pm Pst https://...       en
# 6   @NataliiaKulak It is so depressing what you mu...       en
# 7   @ZelenskaUA All the best. May the force be wit...       en
# 8   Russian missiles strike Kyiv as Zelenskyy pled...       en
# 9   Russian missiles strike Kyiv as Zelenskyy pled...       en
# 10  C$23.74 - #FreeShipping | Time is Running Out ...       en
# 11  Here's a New Year's resolution: resist the tem...       en
# 12  3-0 #TeamCanada!!! Cruising over #Sweden curre...       en
# 13  3-0 BABY!!!!! LETS FUCKING GO BOYS #WorldJunio...       en
# 14  Stankoven leading large for #Canada tonight.  ...       en
# 15  @Taurevanime pre #Merkel betrayal reveal #Russ...       en
# 16  #Canada’s Western Hudson Bay #polarbear popula...       en
# 17  #RussianBankPanic &amp; the average #russian i...       en
# 18  While many people welcome the removal of borde...       en
# 19  #HappyNewYear / #GloryToUkraine \n\nI'd like t...       en

# %%
import matplotlib.pyplot as plt

language_counts = df_combined2.groupby("language").size().sort_values(ascending=False)[0:20].plot.bar(figsize=(12,6),
                                                                                         title="Top 20 Languages by Frequency",
                                                                                         xlabel="Language Code",
                                                                                         ylabel="Number of Tweets",
                                                                                         rot=90
                                                                                         );

plt.xticks(rotation=0)
plt.show()

# %%
df_combined2["cleaned_text"].head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-426937e27f5d> in <cell line: 1>()
# ----> 1 df_combined2["cleaned_text"].head(10)
#
# NameError: name 'df_combined2' is not defined

# %%
# Lowercase everything
df_combined2["cleaned_text"] = df_combined2["text"].str.lower()
# check
df_combined2["cleaned_text"].head(10)
# Out:
# 0    full video, i dare you not to shed a single te...
# 1    @rusmission_eu @mfa_russia @rusmission_oic @am...
# 2    happy new year to you all! from the uk! 🇬🇧 wha...
# 3    the enemy conducted reconnaissance in battle  ...
# 4    happy new year, dear friends!!! year of our vi...
# 5    the night cap airs 6pm pst to 7pm pst https://...
# 6    @nataliiakulak it is so depressing what you mu...
# 7    @zelenskaua all the best. may the force be wit...
# 8    russian missiles strike kyiv as zelenskyy pled...
# 9    russian missiles strike kyiv as zelenskyy pled...
# Name: cleaned_text, dtype: object

# %%
# !pip install emoji --upgrade
import emoji

# !pip install tweet-preprocessor
import preprocessor as p
# Out:
# Collecting emoji
#   Downloading emoji-2.8.0-py2.py3-none-any.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 8.9 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.8.0
# Collecting tweet-preprocessor
#   Downloading tweet_preprocessor-0.6.0-py3-none-any.whl (27 kB)
# Installing collected packages: tweet-preprocessor
# Successfully installed tweet-preprocessor-0.6.0

# %%
def remove_unnecessary(text):
    # INPUT: string (tweet)
    # OUTPUT: string without URLs, mentions, hashtags, digist, and emojis (and smileys)
    p.set_options(p.OPT.URL, p.OPT.MENTION, p.OPT.HASHTAG, p.OPT.NUMBER, p.OPT.EMOJI, p.OPT.SMILEY)
    result = p.clean(text)
    return result

df_combined2["cleaned_text"] = df_combined2["cleaned_text"].map(remove_unnecessary)
# check
df_combined2["cleaned_text"].head(10)
